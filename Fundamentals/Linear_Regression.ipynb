# %% [markdown]
# **Linear Regression**
#
# Linear regression is a fundamental statistical method used for modeling the relationship between a dependent variable and one or more independent variables. It assumes a linear relationship between the independent variables (also known as predictors, features, or explanatory variables) and the dependent variable (also known as the response variable).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([ 14.8, 10.0, 3.0, 7.6, 17.4, 7.2, 2.4, 16.2, 5.0, 10.0, 3.2, 3.2, 4.8, 7.8, 9.8]).reshape(-1, 1)  # x represents temperature
y = np.array([8.1, 4.7, 1.7, 3.6, 8.7, 3.2, 1.0, 8.0, 2.4, 6, 1.1, 1.3, 2.4, 3.9, 3.8]) # y represents energy usage

plt.scatter(x, y)
plt.xlabel("Temperature")
plt.ylabel("Energy Usage")
plt.show()

# %%
# Create and train the model
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
predicted_usage = model.predict(x)
plt.scatter(x , y, color = 'blue')
plt.plot(x, predicted_usage, color = 'green')
plt.xlabel("Temperature")
plt.ylabel("Energy Usage")
# Out:
# Text(0, 0.5, 'Energy Usage')
